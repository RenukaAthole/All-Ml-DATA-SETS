# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv("spotify.csv")

# %%
df
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df.tail()
# Out:
#     Unnamed: 0                                     Track.Name  \
# 45          46                                One Thing Right
# 46          47                                      Te Robaré
# 47          48                                        Happier
# 48          49                                  Call You Mine
# 49          50  Cross Me (feat. Chance the Rapper & PnB Rock)
#
#          Artist.Name    Genre  Beats.Per.Minute  Energy  Danceability  \
# 45        Marshmello  brostep                88      62            66
# 46         Nicky Jam    latin               176      75            67
# 47        Marshmello  brostep               100      79            69
# 48  The Chainsmokers      edm               104      70            59
# 49        Ed Sheeran      pop                95      79            75
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 45              -2        58        44      182               7             5
# ...

# %%
df.sample()
# Out:
#     Unnamed: 0                                         Track.Name Artist.Name  \
# 39          40  fuck, i'm lonely (with Anne-Marie) - from “13 ...        Lauv
#
#         Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# 39  dance pop                95      56            81              -6
#
#     Liveness  Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 39         6        68      199              48             7          78

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        Unnamed: 0  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count    50.00000         50.000000  50.000000      50.00000       50.000000
# mean     25.50000        120.060000  64.060000      71.38000       -5.660000
# std      14.57738         30.898392  14.231913      11.92988        2.056448
# min       1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%      13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%      25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%      37.75000        137.500000  74.750000      79.75000       -4.000000
# max      50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Track.Name          0
# Artist.Name         0
# Genre               0
# Beats.Per.Minute    0
# Energy              0
# Danceability        0
# Loudness..dB..      0
# Liveness            0
# Valence.            0
# Length.             0
# Acousticness..      0
# Speechiness.        0
# Popularity          0
# dtype: int64

# %%
df.rename({"Unnamed: 0":"index",'Track.Name':"Track Name",'Artist.Name':"Artist",'Genre':"style",
           "Beats Per Min":"BeatsPerMin","Loudness..dB..":"Loudness",
        "Valence.":"Valence","Length.":"Length","Acousticness..":"Acousticness","Speechiness.":"Speechiness"},axis=1, inplace=True)
df
# Out:
#     index                                         Track Name  \
# 0       1                                           Señorita
# 1       2                                              China
# 2       3                      boyfriend (with Social House)
# 3       4                    Beautiful People (feat. Khalid)
# 4       5                        Goodbyes (Feat. Young Thug)
# 5       6                  I Don't Care (with Justin Bieber)
# 6       7                                             Ransom
# 7       8                                  How Do You Sleep?
# 8       9                              Old Town Road - Remix
# 9      10                                            bad guy
# 10     11                                           Callaita
# 11     12              Loco Contigo (feat. J. Balvin & Tyga)
# 12     13                                  Someone You Loved
# 13     14                                 Otro Trago - Remix
# ...

# %%
df.rename({"index":"Index","style":"Style"},axis=1,inplace=True)
df
# Out:
#     Index                                         Track Name  \
# 0       1                                           Señorita
# 1       2                                              China
# 2       3                      boyfriend (with Social House)
# 3       4                    Beautiful People (feat. Khalid)
# 4       5                        Goodbyes (Feat. Young Thug)
# 5       6                  I Don't Care (with Justin Bieber)
# 6       7                                             Ransom
# 7       8                                  How Do You Sleep?
# 8       9                              Old Town Road - Remix
# 9      10                                            bad guy
# 10     11                                           Callaita
# 11     12              Loco Contigo (feat. J. Balvin & Tyga)
# 12     13                                  Someone You Loved
# 13     14                                 Otro Trago - Remix
# ...

# %%
df.describe(include='object')
# Out:
#        Track Name      Artist      Style
# count          50          50         50
# unique         50          38         21
# top      Señorita  Ed Sheeran  dance pop
# freq            1           4          8

# %%
df.describe(include='int')
# Out:
#           Index  Beats.Per.Minute     Energy  Danceability   Loudness  \
# count  50.00000         50.000000  50.000000      50.00000  50.000000
# mean   25.50000        120.060000  64.060000      71.38000  -5.660000
# std    14.57738         30.898392  14.231913      11.92988   2.056448
# min     1.00000         85.000000  32.000000      29.00000 -11.000000
# 25%    13.25000         96.000000  55.250000      67.00000  -6.750000
# 50%    25.50000        104.500000  66.500000      73.50000  -6.000000
# 75%    37.75000        137.500000  74.750000      79.75000  -4.000000
# max    50.00000        190.000000  88.000000      90.00000  -2.000000
#
#         Liveness    Valence      Length  Acousticness  Speechiness  Popularity
# count  50.000000  50.000000   50.000000     50.000000    50.000000   50.000000
# mean   14.660000  54.600000  200.960000     22.160000    12.480000   87.500000
# std    11.118306  22.336024   39.143879     18.995553    11.161596    4.491489
# ...

# %%
len(df.columns)
# Out:
# 14

# %%
df.isnull().sum()
# Out:
# Index               0
# Track Name          0
# Artist              0
# Style               0
# Beats.Per.Minute    0
# Energy              0
# Danceability        0
# Loudness            0
# Liveness            0
# Valence             0
# Length              0
# Acousticness        0
# Speechiness         0
# Popularity          0
# dtype: int64

# %%
df.shape
# Out:
# (50, 14)

# %%
df["Artist"].value_counts()
# Out:
# Ed Sheeran          4
# Shawn Mendes        2
# Lil Nas X           2
# J Balvin            2
# Sech                2
# Billie Eilish       2
# The Chainsmokers    2
# Marshmello          2
# Post Malone         2
# Ariana Grande       2
# ROSALÍA             1
# Khalid              1
# Lady Gaga           1
# Daddy Yankee        1
# Kygo                1
# Lauv                1
# Jonas Brothers      1
# Martin Garrix       1
# Katy Perry          1
# Young Thug          1
# Maluma              1
# Taylor Swift        1
# Jhay Cortez         1
# Ali Gatie           1
# Tones and I         1
# Lunay               1
# Anuel AA            1
# MEDUZA              1
# Lizzo               1
# Y2K                 1
# Chris Brown         1
# Drake               1
# Lewis Capaldi       1
# DJ Snake            1
# Bad Bunny           1
# Sam Smith           1
# Lil Tecca           1
# Nicky Jam           1
# Name: Artist, dtype: int64

# %%
df["Track Name"].value_counts()
# Out:
# Señorita                                                                1
# Antisocial (with Travis Scott)                                          1
# It's You                                                                1
# Con Calma                                                               1
# QUE PRETENDES                                                           1
# Takeaway                                                                1
# 7 rings                                                                 1
# 0.958333333333333                                                       1
# The London (feat. J. Cole & Travis Scott)                               1
# Never Really Over                                                       1
# Summer Days (feat. Macklemore & Patrick Stump of Fall Out Boy)          1
# Otro Trago                                                              1
# Sucker                                                                  1
# ...

# %%
df["Style"].value_counts()
# Out:
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# reggaeton           2
# reggaeton flow      2
# panamanian pop      2
# canadian pop        2
# electropop          2
# country rap         2
# dfw rap             2
# brostep             2
# trap music          1
# escape room         1
# pop house           1
# australian pop      1
# atl hip hop         1
# big room            1
# boy band            1
# r&b en espanol      1
# Name: Style, dtype: int64

# %%
df["Beats.Per.Minute"].value_counts()
# Out:
# 176    5
# 96     4
# 98     3
# 93     3
# 135    2
# 92     2
# 85     2
# 100    2
# 124    2
# 136    2
# 95     2
# 104    2
# 114    1
# 152    1
# 138    1
# 140    1
# 94     1
# 117    1
# 130    1
# 154    1
# 158    1
# 105    1
# 90     1
# 101    1
# 110    1
# 111    1
# 180    1
# 102    1
# 150    1
# 190    1
# 88     1
# Name: Beats.Per.Minute, dtype: int64

# %%
df["Energy"].value_counts()
# Out:
# 79    5
# 68    4
# 62    4
# 65    3
# 59    3
# 82    2
# 71    2
# 39    2
# 70    2
# 45    2
# 72    1
# 32    1
# 88    1
# 55    1
# 86    1
# 73    1
# 56    1
# 40    1
# 69    1
# 51    1
# 74    1
# 46    1
# 78    1
# 81    1
# 48    1
# 50    1
# 41    1
# 43    1
# 64    1
# 80    1
# 75    1
# Name: Energy, dtype: int64

# %%
df["Danceability"].value_counts()
# Out:
# 75    4
# 80    3
# 70    3
# 69    3
# 76    2
# 82    2
# 81    2
# 72    2
# 84    2
# 73    2
# 78    2
# 77    2
# 88    2
# 66    2
# 64    2
# 67    2
# 29    1
# 57    1
# 74    1
# 90    1
# 83    1
# 68    1
# 79    1
# 50    1
# 61    1
# 48    1
# 58    1
# 40    1
# 59    1
# Name: Danceability, dtype: int64

# %%
df["Loudness"].value_counts()
# Out:
# -6     13
# -4     11
# -5      8
# -7      6
# -8      3
# -11     3
# -3      3
# -2      2
# -9      1
# Name: Loudness, dtype: int64

# %%
df["Liveness"].value_counts()
# Out:
# 11    6
# 8     5
# 7     5
# 9     4
# 6     4
# 12    4
# 10    3
# 14    2
# 16    2
# 13    2
# 36    2
# 32    1
# 17    1
# 58    1
# 5     1
# 23    1
# 44    1
# 19    1
# 18    1
# 15    1
# 24    1
# 41    1
# Name: Liveness, dtype: int64

# %%
df["Valence"].value_counts()
# Out:
# 68    3
# 75    2
# 32    2
# 61    2
# 50    2
# 91    2
# 40    2
# 80    2
# 35    2
# 18    2
# 39    1
# 33    1
# 58    1
# 94    1
# 66    1
# 62    1
# 54    1
# 87    1
# 95    1
# 73    1
# 44    1
# 36    1
# 41    1
# 48    1
# 63    1
# 43    1
# 14    1
# 10    1
# 76    1
# 45    1
# 38    1
# 24    1
# 56    1
# 64    1
# 23    1
# 84    1
# 55    1
# 70    1
# 67    1
# Name: Valence, dtype: int64

# %%
df["Length"].value_counts()
# Out:
# 191    2
# 202    2
# 182    2
# 162    2
# 210    2
# 198    2
# 164    1
# 213    1
# 193    1
# 222    1
# 179    1
# 176    1
# 200    1
# 224    1
# 214    1
# 216    1
# 218    1
# 195    1
# 181    1
# 199    1
# 228    1
# 171    1
# 226    1
# 309    1
# 266    1
# 302    1
# 186    1
# 175    1
# 220    1
# 131    1
# 157    1
# 194    1
# 251    1
# 185    1
# 288    1
# 205    1
# 261    1
# 243    1
# 158    1
# 161    1
# 173    1
# 153    1
# 115    1
# 206    1
# Name: Length, dtype: int64

# %%
df["Acousticness"].value_counts()
# Out:
# 12    4
# 4     3
# 2     3
# 7     2
# 14    2
# 11    2
# 18    2
# 19    2
# 37    2
# 5     2
# 15    2
# 1     1
# 69    1
# 13    1
# 39    1
# 22    1
# 24    1
# 59    1
# 23    1
# 3     1
# 48    1
# 34    1
# 49    1
# 25    1
# 36    1
# 8     1
# 56    1
# 10    1
# 75    1
# 28    1
# 60    1
# 33    1
# 9     1
# 45    1
# 21    1
# Name: Acousticness, dtype: int64

# %%
df["Speechiness"].value_counts()
# Out:
# 3     7
# 5     6
# 6     6
# 7     4
# 4     3
# 8     2
# 9     2
# 15    2
# 10    2
# 12    2
# 38    1
# 31    1
# 20    1
# 29    1
# 32    1
# 19    1
# 11    1
# 30    1
# 46    1
# 25    1
# 33    1
# 28    1
# 34    1
# 13    1
# Name: Speechiness, dtype: int64

# %%
df["Popularity"].value_counts()
# Out:
# 89    8
# 88    8
# 91    7
# 87    4
# 84    3
# 90    3
# 92    3
# 83    2
# 86    2
# 82    2
# 79    1
# 80    1
# 70    1
# 93    1
# 95    1
# 94    1
# 85    1
# 78    1
# Name: Popularity, dtype: int64

# %%
df.dtypes
# Out:
# Index                int64
# Track Name          object
# Artist              object
# Style               object
# Beats.Per.Minute     int64
# Energy               int64
# Danceability         int64
# Loudness             int64
# Liveness             int64
# Valence              int64
# Length               int64
# Acousticness         int64
# Speechiness          int64
# Popularity           int64
# dtype: object

# %%
df['Style'].value_counts().plot(kind='bar',color=['tan','silver'])
# Out:
# <AxesSubplot:>

# %%
df['Length'].plot(kind='kde',c="r")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Energy'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Speechiness'].plot(kind='kde',c='r')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Liveness'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Liveness'>

# %%
sorted_df = df.sort_values('Popularity',ascending = False).head(5)
sorted_df
# Out:
#     Index                                Track Name         Artist  \
# 9      10                                   bad guy  Billie Eilish
# 4       5               Goodbyes (Feat. Young Thug)    Post Malone
# 10     11                                  Callaita      Bad Bunny
# 14     15  Money In The Grave (Drake ft. Rick Ross)          Drake
# 1       2                                     China       Anuel AA
#
#                Style  Beats.Per.Minute  Energy  Danceability  Loudness  \
# 9         electropop               135      43            70       -11
# 4            dfw rap               150      65            58        -4
# 10         reggaeton               176      62            61        -5
# 14  canadian hip hop               101      50            83        -4
# 1     reggaeton flow               105      81            79        -4
#
#     Liveness  Valence  Length  Acousticness  Speechiness  Popularity
# ...

# %%
sorted_df.plot(kind="bar",xlabel="Poularity").set(title="Top Popular song")
# Out:
# [Text(0.5, 1.0, 'Top Popular song')]

# %%
df[["Artist"]].iloc[18]
# Out:
# Artist    Y2K
# Name: 18, dtype: object

# %%
df.corr()
# Out:
#                      Index  Beats.Per.Minute    Energy  Danceability  \
# Index             1.000000         -0.259193  0.102649      0.122691
# Beats.Per.Minute -0.259193          1.000000  0.043756     -0.094183
# Energy            0.102649          0.043756  1.000000      0.018254
# Danceability      0.122691         -0.094183  0.018254      1.000000
# Loudness          0.011914          0.017016  0.670794      0.016255
# Liveness          0.270659         -0.167286  0.162768     -0.149636
# Valence           0.137329         -0.011586  0.438820      0.172829
# Length           -0.065844         -0.139288  0.224677     -0.000185
# Acousticness     -0.015993         -0.031450 -0.339892     -0.098165
# Speechiness      -0.257506          0.557052 -0.089860     -0.103472
# Popularity       -0.160680          0.196097 -0.080295     -0.071413
#
#                   Loudness  Liveness   Valence    Length  Acousticness  \
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(data = df,x="Energy", y="Loudness"  ,color="c").set(title="Loudness vs Energy")
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy')]

# %%
sns.regplot(data = df,x="Acousticness", y="Popularity"  ,color="blue").set(title="Popularity vs Acousticness")
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness')]

# %%
#top 5 popular Artist name
top_artist=df.groupby("Artist").count().sort_values(by="Track Name",ascending=False)["Track Name"][:5]
top_artist
# Out:
# Artist
# Ed Sheeran      4
# Lil Nas X       2
# Shawn Mendes    2
# Marshmello      2
# Post Malone     2
# Name: Track Name, dtype: int64

# %%
top_artist.plot.bar()
# Out:
# <AxesSubplot:xlabel='Artist'>

# %%
#top Loudest tracks
loudest_track=df[["Loudness","Track Name"]].sort_values(by="Loudness")[:5]
loudest_track
# Out:
#     Loudness                       Track Name
# 24       -11     bad guy (with Justin Bieber)
# 31       -11                          7 rings
# 9        -11                          bad guy
# 43        -9                             Talk
# 3         -8  Beautiful People (feat. Khalid)

# %%
sns.barplot(x="Loudness",y="Track Name",data=loudest_track)
# Out:
# <AxesSubplot:xlabel='Loudness', ylabel='Track Name'>

# %%
#dancability
top_dance=df[["Danceability","Track Name","Artist"]].sort_values(by="Danceability",ascending=False)[:5]
top_dance
# Out:
#     Danceability             Track Name          Artist
# 43            90                   Talk          Khalid
# 44            88             Con Altura         ROSALÍA
# 8             88  Old Town Road - Remix       Lil Nas X
# 38            84                 Sucker  Jonas Brothers
# 18            84                 Lalala             Y2K

# %%
sns.barplot(x="Danceability",y="Artist",data=top_dance)
# Out:
# <AxesSubplot:xlabel='Danceability', ylabel='Artist'>

# %%
sns.boxenplot(data=df,x="Energy")
# Out:
# <AxesSubplot:xlabel='Energy'>

# %%
sns.kdeplot(data=df,x="Danceability", y="Liveness")
# Out:
# <AxesSubplot:xlabel='Danceability', ylabel='Liveness'>

# %%
sns.lmplot(data=df,x="Danceability", y="Liveness")

# %%
#max length 
length=df[["Length","Track Name"]].sort_values(by="Length",ascending=False)[:5]
length
# Out:
#     Length                 Track Name
# 22     309       No Me Conoce - Remix
# 1      302                      China
# 13     288         Otro Trago - Remix
# 23     266            Soltera - Remix
# 15     261  No Guidance (feat. Drake)

# %%
sns.barplot(x="Length",y="Track Name",data=length)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Track Name'>

# %%
#min length 
length=df[["Length","Track Name"]].sort_values(by="Length",ascending=True).head(5)
length
# Out:
#     Length                                     Track Name
# 21     115                                         Panini
# 6      131                                         Ransom
# 20     153                            Piece Of Your Heart
# 8      157                          Old Town Road - Remix
# 17     158  Sunflower - Spider-Man: Into the Spider-Verse

# %%
sns.stripplot(x="Length",y="Track Name",data=length).grid()

# %%
data1=df.aggregate('mean')
data1
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14912\3624461036.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data1=df.aggregate('mean')
# Index                25.50
# Beats.Per.Minute    120.06
# Energy               64.06
# Danceability         71.38
# Loudness             -5.66
# Liveness             14.66
# Valence              54.60
# Length              200.96
# Acousticness         22.16
# Speechiness          12.48
# Popularity           87.50
# dtype: float64

# %%
df.head(2)
# Out:
#    Index Track Name        Artist           Style  Beats.Per.Minute  Energy  \
# 0      1   Señorita  Shawn Mendes    canadian pop               117      55
# 1      2      China      Anuel AA  reggaeton flow               105      81
#
#    Danceability  Loudness  Liveness  Valence  Length  Acousticness  \
# 0            76        -6         8       75     191             4
# 1            79        -4         8       61     302             8
#
#    Speechiness  Popularity
# 0            3          79
# 1            9          92

# %%
#top 5 high BeatsPerMin Artist name
beats=df.groupby("Artist").count().sort_values(by="Beats.Per.Minute",ascending=False)["Beats.Per.Minute"]
beats
# Out:
# Artist
# Ed Sheeran          4
# Lil Nas X           2
# Shawn Mendes        2
# Marshmello          2
# Post Malone         2
# Sech                2
# J Balvin            2
# The Chainsmokers    2
# Billie Eilish       2
# Ariana Grande       2
# Taylor Swift        1
# Tones and I         1
# Lizzo               1
# Sam Smith           1
# ROSALÍA             1
# Y2K                 1
# Nicky Jam           1
# Martin Garrix       1
# Maluma              1
# MEDUZA              1
# Lunay               1
# Ali Gatie           1
# Lil Tecca           1
# Anuel AA            1
# Lewis Capaldi       1
# Lauv                1
# Lady Gaga           1
# Kygo                1
# Khalid              1
# Katy Perry          1
# Jonas Brothers      1
# Jhay Cortez         1
# Drake               1
# Daddy Yankee        1
# DJ Snake            1
# Chris Brown         1
# Bad Bunny           1
# Young Thug          1
# Name: Beats.Per.Minute, dtype: int64

# %%
beats.plot.bar()
# Out:
# <AxesSubplot:xlabel='Artist'>

# %%
sns.displot(data=df,x='Valence',kde=True,bins=30)

# %%
sns.histplot(df['Valence'],edgecolor='r',bins=20,color='c')
# Out:
# <AxesSubplot:xlabel='Valence', ylabel='Count'>

# %%
df.head(3)
# Out:
#    Index                     Track Name         Artist           Style  \
# 0      1                       Señorita   Shawn Mendes    canadian pop
# 1      2                          China       Anuel AA  reggaeton flow
# 2      3  boyfriend (with Social House)  Ariana Grande       dance pop
#
#    Beats.Per.Minute  Energy  Danceability  Loudness  Liveness  Valence  \
# 0               117      55            76        -6         8       75
# 1               105      81            79        -4         8       61
# 2               190      80            40        -4        16       70
#
#    Length  Acousticness  Speechiness  Popularity
# 0     191             4            3          79
# 1     302             8            9          92
# 2     186            12           46          85

# %%
sns.swarmplot(data=df,x='Energy',y='Length')
# Out:
# <AxesSubplot:xlabel='Energy', ylabel='Length'>

# %%
sns.pairplot(df)
