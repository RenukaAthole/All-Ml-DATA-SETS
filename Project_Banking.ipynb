# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Banking.csv")

# %%
df
# Out:
#      Client ID              Name  Age  Location ID Joined Bank  \
# 0     IND81288     Raymond Mills   24        34324    5/6/2019
# 1     IND65833     Julia Spencer   23        42205  12/10/2001
# 2     IND47499    Stephen Murray   27         7314   1/25/2010
# 3     IND72498    Virginia Garza   40        34594   3/28/2019
# 4     IND60181   Melissa Sanders   46        41269   7/20/2012
# ...        ...               ...  ...          ...         ...
# 2995  IND66827         Earl Hall   82         8760   10/9/2014
# 2996  IND40556  Billy Williamson   44        32837    2/5/2009
# 2997  IND72414      Victor Black   70        36088  12/29/2009
# 2998  IND46652       Andrew Ford   56        24871   2/13/2006
# 2999  IND40216        Amy Nguyen   79        38518   12/8/2005
#
#           Banking Contact Nationality                     Occupation  \
# 0          Anthony Torres    American           Safety Technician IV
# ...

# %%
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324    5/6/2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  12/10/2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314   1/25/2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594   3/28/2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269   7/20/2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.tail()
# Out:
#      Client ID              Name  Age  Location ID Joined Bank  \
# 2995  IND66827         Earl Hall   82         8760   10/9/2014
# 2996  IND40556  Billy Williamson   44        32837    2/5/2009
# 2997  IND72414      Victor Black   70        36088  12/29/2009
# 2998  IND46652       Andrew Ford   56        24871   2/13/2006
# 2999  IND40216        Amy Nguyen   79        38518   12/8/2005
#
#           Banking Contact Nationality                     Occupation  \
# 2995       Joshua Bennett    American       Accounting Assistant III
# 2996          Dennis Ruiz    European                      Paralegal
# 2997          Joshua Ryan    American                Statistician IV
# 2998  Nicholas Cunningham    European  Human Resources Assistant III
# 2999           Joe Hanson    American            Biostatistician III
#
#      Fee Structure Loyalty Classification  ...  Bank Deposits  \
# 2995          High                   Gold  ...     1089957.03
# ...

# %%
df.sample()
# Out:
#      Client ID         Name  Age  Location ID Joined Bank Banking Contact  \
# 1650  IND74692  Anne Hunter   70        20712   4/26/2020   Keith Griffin
#
#      Nationality    Occupation Fee Structure Loyalty Classification  ...  \
# 1650    European  Developer II          High               Platinum  ...
#
#       Bank Deposits  Checking Accounts  Saving Accounts  \
# 1650     1312115.54          493667.23        837675.35
#
#       Foreign Currency Account  Business Lending  Properties Owned  \
# 1650                  53240.01        1279233.84                 2
#
#       Risk Weighting  BRId  GenderId  IAId
# 1650               4     3         1    19
#
# [1 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# dtype: int64

# %%
df["Nationality"].value_counts()
# Out:
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: Nationality, dtype: int64

# %%
df["Joined Bank"].value_counts()
# Out:
# 2/3/2020      4
# 6/19/2020     4
# 3/17/2019     4
# 6/17/2021     3
# 8/18/2007     3
#              ..
# 1/28/2011     1
# 10/29/2020    1
# 7/22/2020     1
# 12/1/2011     1
# 12/8/2005     1
# Name: Joined Bank, Length: 2579, dtype: int64

# %%
df["Occupation"].value_counts()
# Out:
# Structural Analysis Engineer    28
# Associate Professor             28
# Recruiter                       25
# Human Resources Manager         24
# Account Coordinator             24
#                                 ..
# Office Assistant IV              8
# Automation Specialist I          7
# Computer Systems Analyst I       6
# Developer III                    5
# Senior Sales Associate           4
# Name: Occupation, Length: 195, dtype: int64

# %%
df["Fee Structure"].value_counts()
# Out:
# High    1476
# Mid      962
# Low      562
# Name: Fee Structure, dtype: int64

# %%
df["Fee Structure"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Fee Structure'>

# %%
df["Loyalty Classification"].value_counts()
# Out:
# Jade        1331
# Silver       767
# Gold         585
# Platinum     317
# Name: Loyalty Classification, dtype: int64

# %%
df["Loyalty Classification"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Loyalty Classification'>

# %%
df["Loyalty Classification"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["Estimated Income"].value_counts()
# Out:
# 75384.77     1
# 341878.19    1
# 325675.36    1
# 144361.23    1
# 127999.76    1
#             ..
# 96970.50     1
# 267003.90    1
# 126128.01    1
# 41843.49     1
# 56826.53     1
# Name: Estimated Income, Length: 3000, dtype: int64

# %%
df["Superannuation Savings"].value_counts()
# Out:
# 13692.28    2
# 45239.43    2
# 16256.50    2
# 17677.95    1
# 9748.53     1
#            ..
# 20714.37    1
# 44738.49    1
# 11447.00    1
# 44556.80    1
# 8855.30     1
# Name: Superannuation Savings, Length: 2997, dtype: int64

# %%
df["Amount of Credit Cards"].value_counts()
# Out:
# 1    1922
# 2     765
# 3     313
# Name: Amount of Credit Cards, dtype: int64

# %%
df["Amount of Credit Cards"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["Credit Card Balance"].value_counts()
# Out:
# 647.72     2
# 2509.62    2
# 2470.82    2
# 2552.68    2
# 484.54     1
#           ..
# 2675.36    1
# 1898.92    1
# 2736.66    1
# 2900.64    1
# 1494.69    1
# Name: Credit Card Balance, Length: 2996, dtype: int64

# %%
df["Bank Loans"].value_counts()
# Out:
# 0.00          27
# 639113.19      2
# 776242.92      1
# 540883.97      1
# 510642.72      1
#               ..
# 1333483.38     1
# 1561287.22     1
# 322551.54      1
# 532788.31      1
# 285640.66      1
# Name: Bank Loans, Length: 2973, dtype: int64

# %%
df["Bank Deposits"].value_counts()
# Out:
# 0.00          34
# 1485828.64     1
# 1675743.29     1
# 748509.94      1
# 1013382.00     1
#               ..
# 1112405.11     1
# 591197.27      1
# 1002810.16     1
# 153872.47      1
# 65617.66       1
# Name: Bank Deposits, Length: 2967, dtype: int64

# %%
df["Checking Accounts"].value_counts()
# Out:
# 0.00          34
# 603617.88      1
# 1122019.42     1
# 209582.78      1
# 560738.04      1
#               ..
# 460693.03      1
# 321680.87      1
# 990871.95      1
# 100813.00      1
# 77769.08       1
# Name: Checking Accounts, Length: 2967, dtype: int64

# %%
df["Saving Accounts"].value_counts()
# Out:
# 0.00         34
# 607332.46     1
# 237955.55     1
# 373656.16     1
# 96473.97      1
#              ..
# 709354.90     1
# 132236.92     1
# 239480.62     1
# 151325.62     1
# 32371.38      1
# Name: Saving Accounts, Length: 2967, dtype: int64

# %%
df["Foreign Currency Account"].value_counts()
# Out:
# 12249.96     1
# 45753.21     1
# 103068.96    1
# 1861.28      1
# 41443.20     1
#             ..
# 20784.64     1
# 20617.59     1
# 26945.57     1
# 19140.10     1
# 8992.36      1
# Name: Foreign Currency Account, Length: 3000, dtype: int64

# %%
df["Business Lending"].value_counts()
# Out:
# 0.00          14
# 1134475.30     1
# 1025028.05     1
# 2354614.10     1
# 1032174.49     1
#               ..
# 1858738.59     1
# 563428.75      1
# 114520.07      1
# 1886984.35     1
# 329412.55      1
# Name: Business Lending, Length: 2987, dtype: int64

# %%
df["Properties Owned"].value_counts()
# Out:
# 2    777
# 1    776
# 3    742
# 0    705
# Name: Properties Owned, dtype: int64

# %%
df["Risk Weighting"].value_counts()
# Out:
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: Risk Weighting, dtype: int64

# %%
df["BRId"].value_counts()
# Out:
# 3    1352
# 1     660
# 2     495
# 4     493
# Name: BRId, dtype: int64

# %%
df["GenderId"].value_counts()
# Out:
# 2    1512
# 1    1488
# Name: GenderId, dtype: int64

# %%
df["IAId"].value_counts()
# Out:
# 1     177
# 3     177
# 4     177
# 8     177
# 2     177
# 11    176
# 15    176
# 14    176
# 13    176
# 12    176
# 10    176
# 9     176
# 7      89
# 6      89
# 5      89
# 16     88
# 17     88
# 18     88
# 19     88
# 20     88
# 21     88
# 22     88
# Name: IAId, dtype: int64

# %%
df["IAId"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='IAId'>

# %%
df["GenderId"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='GenderId'>

# %%
df["GenderId"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df["BRId"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='BRId'>

# %%
df["Risk Weighting"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Risk Weighting'>

# %%
df["Properties Owned"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Properties Owned'>

# %%
df["Amount of Credit Cards"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Amount of Credit Cards'>

# %%
df["Amount of Credit Cards"].plot(kind="kde",x="Amount of Credit Cards")
plt.grid()
plt.show()

# %%
df["Properties Owned"].plot(kind="hist",x="Properties Owned",color="r")
plt.title("Properties Owned hist plot")
plt.show()

# %%
sns.scatterplot(df["Properties Owned"],df["Risk Weighting"])
plt.grid()
plt.show()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.scatter(data=df,x="Risk Weighting",y="Properties Owned",color="r")
plt.xlabel("Risk Weighting")
plt.ylabel("Properties Owned")
plt.grid(color="blue")

# %%
sns.kdeplot(data=df,x="Amount of Credit Cards",y="Properties Owned",color="yellow")
# Out:
# <AxesSubplot:xlabel='Amount of Credit Cards', ylabel='Properties Owned'>

# %%
sns.kdeplot(data=df,x="Amount of Credit Cards",y="Properties Owned",color="yellow",hue="Risk Weighting")
# Out:
# <AxesSubplot:xlabel='Amount of Credit Cards', ylabel='Properties Owned'>

# %%
sns.barplot(data=df,x="Amount of Credit Cards",y="Properties Owned",color="yellow",hue="Risk Weighting")
# Out:
# <AxesSubplot:xlabel='Amount of Credit Cards', ylabel='Properties Owned'>

# %%
sns.scatterplot(data=df,x="Amount of Credit Cards",y="Properties Owned",color="yellow",hue="Risk Weighting")
# Out:
# <AxesSubplot:xlabel='Amount of Credit Cards', ylabel='Properties Owned'>

# %%
sns.boxplot(data=df,x="BRId",y="GenderId",color="yellow",hue="Risk Weighting")
# Out:
# <AxesSubplot:xlabel='BRId', ylabel='GenderId'>

# %%
sns.stripplot(data=df,x="IAId",y="GenderId",color="yellow",hue="Risk Weighting")
# Out:
# <AxesSubplot:xlabel='IAId', ylabel='GenderId'>

# %%
sns.boxenplot(data=df,x="Amount of Credit Cards",y="GenderId",color="yellow")
# Out:
# <AxesSubplot:xlabel='Amount of Credit Cards', ylabel='GenderId'>

# %%
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324    5/6/2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  12/10/2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314   1/25/2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594   3/28/2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269   7/20/2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
#top 5 free structure
fee=df.groupby("Fee Structure").count().sort_values(by="Loyalty Classification",ascending=False)["Loyalty Classification"][:5]
fee
# Out:
# Fee Structure
# High    1476
# Mid      962
# Low      562
# Name: Loyalty Classification, dtype: int64

# %%
fee.plot.pie()
# Out:
# <AxesSubplot:ylabel='Loyalty Classification'>

# %%
fee.plot.barh()
# Out:
# <AxesSubplot:ylabel='Fee Structure'>
